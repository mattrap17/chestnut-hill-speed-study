# %%
sns.histplot(data=df, x='Speed (mph)', hue='Over Limit?', bins=10, kde=True, palette='Set2')
plt.title('Driver Speeds by Speeding Status')
plt.xlabel('Speed (mph)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Clean column name for easier use
df.columns = df.columns.str.strip()

# Plot histogram with KDE
sns.histplot(df['Speed (mph)'], bins=10, kde=True, color='skyblue')

plt.title('Driver Speeds on Chestnut Hill Rd')
plt.xlabel('Speed (mph)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Read and clean
df = pd.read_csv('/content/SpeedinginColchesterCTByTime.csv')

# Fill Speed (mph) NaNs with 0
df['Speed (mph)'] = df['Speed (mph)'].fillna(0)

# Drop rows missing either Bad weather or Saturday/Sunday
df = df.dropna(subset=['Bad weather', 'Saturday/Sunday'])

# Display cleaned table
df.head()
# Out:
#       Date      Time            Location  Unnamed: 3  Speed (mph)  \
# 52  28-Jun  12:01 PM  Chestnut Hill Road         NaN           37
# 53  28-Jun  12:02 PM  Chestnut Hill Road         NaN           38
#
#     Speed Limit Over Limit? Saturday/Sunday Bad weather
# 52           30           Y        Saturday  Light Rain
# 53           30           Y        Saturday  Light Rain
